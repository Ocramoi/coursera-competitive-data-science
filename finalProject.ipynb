# %% [markdown]
# # Imports

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random

sns.set()

# %% [markdown]
# # Training set

# %%
procentagem = 20

train = pd.read_csv("../kaggleData/sales_train.csv",
                    skiprows=lambda i: i>0 and random.random() > (procentagem * 0.01))
train["datetime"] = pd.to_datetime(train["date"],
                                   format="%d.%m.%Y")
train["day_month"] = train["datetime"].dt.day

grouped = train.groupby(by=["shop_id", "date_block_num", "item_id"])

plt.figure(figsize=[18, 18])
pd.plotting.scatter_matrix(train)
plt.show()

# X = []
# y = []
#
# for groupId, group in grouped:
#     X.append(list(groupId))
#     y.append(group["item_cnt_day"].sum())

# %% [markdown]
# # Delete variables
